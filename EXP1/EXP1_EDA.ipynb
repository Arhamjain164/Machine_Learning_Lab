# %% [markdown]
# # Exploratory Data Analysis
#
#
#
# load a CSV dataset from a local file using `pandas.read_csv,,,
# use basic Pandas functions for Exploratory Data Analysis-EDA
# describe and discriminate between basic data types such as categorical, quantitative, continuous, discrete, ordinal, nominal and identifier

# %% [markdown]
# # [Objective 01] LOAD THE DATASET AND EXPLORE

# %% [markdown]
# ## Overview
#
#
#
# Steps for loading a dataset:
#
# 1) Learn as much as you can about the dataset:
#  - Number of rows
#  - Number of columns
#  - Column headers (Is there a "data dictionary"?)
#  - Is there missing data?
#  - Open the raw file and look at it - it may not be formatted the way you expect.
#
# 2) Try loading the dataset using `pandas.read_csv()` and if things aren't acting the way that you expect, investigate until you can get it loading correctly.
#
# 3) Keep in mind that functions like `pandas.read_csv()` have a lot of optional parameters that might help us change the way that data is read in. If you get stuck, google, read the documentation, and try things out.
#
# 4) You might need to type out column headers by hand if they are not provided in a neat format in the original dataset. It can be a drag.

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Learn about the dataset and look at the raw file.

# %%
# Open and read raw CSV
with open("./iris_dirty.csv", "r") as f:
    raw_data = f.read()

print(raw_data)
# Out:
# ,Sepal.Length,Sepal.Width,Petal.Length,Petal.Width,Species
# 1,5.1,3.5,1.4,0.2,Setosa
# 2,4.9,3,1.4,0.2,setosa
# 3,4.7,3.2,1.3,0.2,setosa
# 4,4.6,3.1,1.5,0.2,setosa
# 5,NA,3.6,1.4,0.2,setosa
# 6,5.4,NA,1.7,0.4,setosa
# 7,4.6,3.4,1.4,0.3,setosa
# 8,5,3.4,1.5,0.2,SETOSA
# 9,4.4,2.9,1.4,0.2,setosa
# 10,4.9,NA,1.5,0.1,setosa
# 11,5.4,3.7,1.5,0.2,setosa
# 12,4.8,3.4,1.6,0.2,setosa
# 13,4.8,3,1.4,0.1,setosa
# 14,4.3,3,1.1,0.1,setosa
# 15,5.8,4,1.2,0.2,setosa
# 16,5.7,4.4,1.5,0.4,setosa
# 17,5.4,3.9,1.3,0.4,setosa
# 18,5.1,3.5,1.4,0.3,setosa
# 19,5.7,3.8,1.7,0.3,setosa
# 20,5.1,3.8,1.5,0.3,setosa
# 21,NA,3.4,1.7,0.2,setosa
# 22,5.1,3.7,1.5,0.4,setosa
# 23,4.6,3.6,1,0.2,setosa
# 24,5.1,3.3,1.7,0.5,setosa
# 25,4.8,3.4,1.9,0.2,setosa
# 26,5,3,1.6,0.2,setosa
# 27,5,NA,1.6,0.4,setosa
# 28,5.2,3.5,1.5,0.2,setosa
# 29,5.2,3.4,1.4,0.2,setosa
# 30,4.7,3.2,1.6,0.2,setosa
# 31,4.8,3.1,1.6,0.2,setosa
# 32,5.4,3.4,1.5,0.4,setosa
# 33,5.2,4.1,1.5,0.1,setosa
# 34,5.5,4.2,1.4,0.2,setosa
# 35,4.9,3.1,1.5,0.2,setosa
# 36,5,3.2,1.2,0.2,setosa
# 37,5.5,NA,1.3,0.2,setosa
# 38,4.9,3.6,1.4,0.1,setosa
# 39,4.4,3,1.3,0.2,setosa
# 40,5.1,3.4,1.5,0.2,setosa
# 41,5,3.5,1.3,0.3,setosa
# 42,4.5,2.3,1.3,0.3,setosa
# 43,4.4,3.2,1.3,0.2,setosa
# 44,5,3.5,1.6,0.6,setosa
# 45,5.1,3.8,1.9,0.4,setosa
# 46,NA,3,1.4,0.3,setosa
# 47,5.1,NA,1.6,0.2,setosa
# 48,4.6,3.2,1.4,0.2,setosa
# 49,5.3,3.7,1.5,0.2,setosa
# 50,5,3.3,1.4,0.2,setosa
# 51,7,3.2,4.7,1.4,versicolor
# 52,6.4,3.2,4.5,1.5,versicolor
# 53,6.9,NA,4.9,1.5,versicolor
# 54,5.5,2.3,4,1.3,versicolor
# 55,6.5,2.8,4.6,1.5,versicolor
# 56,5.7,2.8,4.5,1.3,versicolor
# 57,6.3,3.3,4.7,1.6,versicolor
# 58,4.9,2.4,3.3,1,versicolor
# 59,6.6,2.9,4.6,1.3,Versicolor
# 60,5.2,2.7,3.9,1.4,versicolor
# 61,5,2,3.5,1,versicolor
# 62,5.9,NA,4.2,1.5,versicolor
# 63,6,2.2,4,1,versicolor
# 64,6.1,2.9,4.7,1.4,VERSICOLOR
# 65,5.6,2.9,3.6,1.3,versicolor
# 66,6.7,3.1,4.4,1.4,versicolor
# 67,5.6,3,4.5,1.5,versicolor
# 68,5.8,2.7,4.1,1,versicolor
# 69,6.2,2.2,4.5,1.5,versicolor
# 70,5.6,2.5,3.9,1.1,versicolor
# 71,5.9,3.2,4.8,1.8,versicolor
# 72,6.1,2.8,4,1.3,versicolor
# 73,6.3,2.5,4.9,1.5,versicolor
# 74,6.1,2.8,4.7,1.2,versicolor
# 75,6.4,2.9,4.3,1.3,versicolor
# 76,6.6,3,4.4,1.4,versicolor
# 77,6.8,2.8,4.8,1.4,versicolor
# 78,6.7,3,5,1.7,versicolor
# 79,6,2.9,4.5,1.5,versicolor
# 80,5.7,2.6,3.5,1,versicolor
# 81,5.5,2.4,3.8,1.1,versicolor
# 82,5.5,2.4,3.7,1,versicolor
# 83,5.8,2.7,3.9,1.2,versicolor
# 84,6,2.7,5.1,1.6,versicolor
# 85,5.4,3,4.5,1.5,versicolor
# 86,6,3.4,4.5,1.6,versicolor
# 87,NA,3.1,4.7,1.5,versicolor
# 88,6.3,2.3,4.4,1.3,versicolor
# 89,5.6,NA,4.1,1.3,versicolor
# 90,5.5,2.5,4,1.3,versicolor
# 91,5.5,2.6,4.4,1.2,versicolor
# 92,6.1,3,4.6,1.4,versicolor
# 93,5.8,2.6,4,1.2,versicolor
# 94,5,2.3,3.3,1,versicolor
# 95,5.6,2.7,4.2,1.3,versicolor
# 96,5.7,3,4.2,1.2,versicolor
# 97,5.7,2.9,4.2,1.3,versicolor
# 98,6.2,2.9,4.3,1.3,versicolor
# 99,5.1,2.5,3,1.1,versicolor
# 100,5.7,2.8,4.1,1.3,versicolor
# 101,6.3,3.3,6,2.5,virginica
# 102,5.8,2.7,5.1,1.9,virginica
# 103,7.1,3,5.9,2.1,virginica
# 104,6.3,2.9,5.6,1.8,virginica
# 105,6.5,3,5.8,2.2,virginica
# 106,7.6,3,6.6,2.1,virginica
# 107,4.9,2.5,4.5,1.7,virginica
# 108,7.3,2.9,6.3,1.8,VIRGINICA
# 109,6.7,2.5,5.8,1.8,virginica
# 110,7.2,3.6,6.1,2.5,virginica
# 111,6.5,3.2,5.1,2,virginica
# 112,6.4,2.7,5.3,1.9,virginica
# 113,6.8,3,5.5,2.1,virginica
# 114,5.7,2.5,5,2,virginica
# 115,5.8,NA,5.1,2.4,virginica
# 116,6.4,3.2,5.3,2.3,virginica
# 117,6.5,3,5.5,1.8,virginica
# 118,7.7,3.8,6.7,2.2,virginica
# 119,7.7,2.6,6.9,2.3,virginica
# 120,6,2.2,5,1.5,virginica
# 121,6.9,3.2,5.7,2.3,virginica
# 122,5.6,2.8,4.9,2,virginica
# 123,7.7,2.8,6.7,2,virginica
# 124,6.3,2.7,4.9,1.8,virginica
# 125,6.7,3.3,5.7,2.1,virginica
# 126,7.2,3.2,6,1.8,virginica
# 127,6.2,2.8,4.8,1.8,virginica
# 128,6.1,3,4.9,1.8,virginica
# 129,6.4,2.8,5.6,2.1,virginica
# 130,7.2,3,5.8,1.6,virginica
# 131,7.4,2.8,6.1,1.9,virginica
# 132,7.9,3.8,6.4,2,virginica
# 133,6.4,2.8,5.6,2.2,virginica
# 134,6.3,NA,5.1,1.5,virginica
# 135,6.1,2.6,5.6,1.4,virginica
# 136,7.7,3,6.1,2.3,virginica
# 137,6.3,3.4,5.6,2.4,virginica
# 138,6.4,3.1,5.5,1.8,virginica
# 139,6,3,4.8,1.8,virginica
# 140,NA,3.1,5.4,2.1,virginica
# 141,6.7,3.1,5.6,2.4,virginica
# 142,6.9,3.1,5.1,2.3,virginica
# 143,NA,2.7,5.1,1.9,virginica
# 144,6.8,NA,5.9,2.3,virginica
# 145,NA,3.3,5.7,2.5,virginica
# 146,6.7,3,5.2,2.3,virginica
# 147,6.3,2.5,5,1.9,virginica
# 148,6.5,3,5.2,2,virginica
# 149,6.2,3.4,5.4,2.3,virginica
# 150,NA,3,5.1,1.8,virginica

# %% [markdown]
# ### Attempt to load it.

# %%
import pandas as pd

# %%
df = pd.read_csv('./iris_dirty.csv')

# %%
#Print the first 5 rows:
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa

# %%
#Print the last 5 rows:
df.tail()
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
#Can you print the first 7 rows?
df.head(7)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa
# 5           6           5.4          NaN           1.7          0.4  setosa
# 6           7           4.6          3.4           1.4          0.3  setosa

# %%
df.duplicated()
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Sepal.Length, Sepal.Width, Petal.Length, Petal.Width, Species]
# Index: []

# %%
# You can look at the documentation, but generally, I recommend Googling.

# %%
# You can provide the column headers if not already present in the dataset and pass it into the read_csv as shown
# column_headers = []
# dataset = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data",
#                     names = column_headers)
columns = [
    "Sepal.Length",
    "Sepal.Width",
    "Petal.Length",
    "Petal.Width",
    "Species"
]
df = pd.read_csv('./iris_dirty.csv',names = columns)

df.head()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# NaN  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 1.0           5.1          3.5           1.4          0.2   Setosa
# 2.0           4.9            3           1.4          0.2   setosa
# 3.0           4.7          3.2           1.3          0.2   setosa
# 4.0           4.6          3.1           1.5          0.2   setosa

# %%
#Print the dimensions
#dimension = rows x columns
df.shape
# Out:
# (151, 5)

# %%
# Print the header again
df.head()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# NaN  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 1.0           5.1          3.5           1.4          0.2   Setosa
# 2.0           4.9            3           1.4          0.2   setosa
# 3.0           4.7          3.2           1.3          0.2   setosa
# 4.0           4.6          3.1           1.5          0.2   setosa

# %%
df.sample(10)
# Out:
#       Sepal.Length Sepal.Width Petal.Length Petal.Width     Species
# 21.0           NaN         3.4          1.7         0.2      setosa
# 148.0          6.5           3          5.2           2   virginica
# 13.0           4.8           3          1.4         0.1      setosa
# 80.0           5.7         2.6          3.5           1  versicolor
# 139.0            6           3          4.8         1.8   virginica
# 11.0           5.4         3.7          1.5         0.2      setosa
# 61.0             5           2          3.5           1  versicolor
# 63.0             6         2.2            4           1  versicolor
# 43.0           4.4         3.2          1.3         0.2      setosa
# 128.0          6.1           3          4.9         1.8   virginica

# %%
df.columns.tolist()
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %%
df
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# NaN    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 1.0             5.1          3.5           1.4          0.2     Setosa
# 2.0             4.9            3           1.4          0.2     setosa
# 3.0             4.7          3.2           1.3          0.2     setosa
# 4.0             4.6          3.1           1.5          0.2     setosa
# ...             ...          ...           ...          ...        ...
# 146.0           6.7            3           5.2          2.3  virginica
# 147.0           6.3          2.5             5          1.9  virginica
# 148.0           6.5            3           5.2            2  virginica
# 149.0           6.2          3.4           5.4          2.3  virginica
# 150.0           NaN            3           5.1          1.8  virginica
#
# [151 rows x 5 columns]

# %% [markdown]
# # [Objective 02](#basic-pandas-functions) - Use basic Pandas functions for Exploratory Data Analysis (EDA)

# %% [markdown]
# ![Workflow.png](data:image/png;base64,...)

# %% [markdown]
# ## Overview
#
# > Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns, to spot anomalies, to test hypotheses and to check assumptions with the help of summary statistics and graphical representations
#
# Exploratory Data Analysis is often the first thing that we'll do when starting out with a new dataset.

# %%
#Learn more about the variables in the dataset using info function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, nan to 150.0
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  143 non-null    object
#  1   Sepal.Width   140 non-null    object
#  2   Petal.Length  151 non-null    object
#  3   Petal.Width   151 non-null    object
#  4   Species       151 non-null    object
# dtypes: object(5)
# memory usage: 7.1+ KB

# %% [markdown]
# #Learn more about each variable

# %%
#Determine the data types
print(df.dtypes)
# Out:
# Sepal.Length    object
# Sepal.Width     object
# Petal.Length    object
# Petal.Width     object
# Species         object
# dtype: object

# %%
# Summary Statistics - using (describe function)
# check if there are non-numeric column
df.describe()
# Out:
#        Sepal.Length Sepal.Width Petal.Length Petal.Width    Species
# count           143         140          151         151        151
# unique           36          24           44          23          9
# top             5.1           3          1.4         0.2  virginica
# freq              9          24           13          29         49

# %% [markdown]
# What is the problem here?

# %% [markdown]
# ????

# %%
# try to exclude non numeric value

# %%
# include all
df.describe(include="all")
# Out:
#        Sepal.Length Sepal.Width Petal.Length Petal.Width    Species
# count           143         140          151         151        151
# unique           36          24           44          23          9
# top             5.1           3          1.4         0.2  virginica
# freq              9          24           13          29         49

# %%
# accesss a specific column of the dataframe
print(df['Species'])
# Out:
# NaN        Species
# 1.0         Setosa
# 2.0         setosa
# 3.0         setosa
# 4.0         setosa
#            ...
# 146.0    virginica
# 147.0    virginica
# 148.0    virginica
# 149.0    virginica
# 150.0    virginica
# Name: Species, Length: 151, dtype: object

# %%
print(df['Sepal.Length'])
# Out:
# NaN      Sepal.Length
# 1.0               5.1
# 2.0               4.9
# 3.0               4.7
# 4.0               4.6
#              ...
# 146.0             6.7
# 147.0             6.3
# 148.0             6.5
# 149.0             6.2
# 150.0             NaN
# Name: Sepal.Length, Length: 151, dtype: object

# %%
print(df['Sepal.Width'].value_counts())
# Out:
# Sepal.Width
# 3              24
# 3.2            12
# 2.8            12
# 3.4            11
# 2.9            10
# 3.1             9
# 2.7             9
# 2.5             8
# 3.3             6
# 2.6             5
# 3.5             5
# 3.8             5
# 2.3             4
# 3.6             4
# 2.2             3
# 3.7             3
# 2.4             3
# Sepal.Width     1
# 4.2             1
# 3.9             1
# 4               1
# 4.1             1
# 4.4             1
# 2               1
# Name: count, dtype: int64

# %%
#sort by values (any specific column)
sorted_values = df.sort_values(by='Petal.Length')
print(sorted_values)
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 23.0            4.6          3.6             1          0.2     setosa
# 14.0            4.3            3           1.1          0.1     setosa
# 36.0              5          3.2           1.2          0.2     setosa
# 15.0            5.8            4           1.2          0.2     setosa
# 42.0            4.5          2.3           1.3          0.3     setosa
# ...             ...          ...           ...          ...        ...
# 106.0           7.6            3           6.6          2.1  virginica
# 123.0           7.7          2.8           6.7            2  virginica
# 118.0           7.7          3.8           6.7          2.2  virginica
# 119.0           7.7          2.6           6.9          2.3  virginica
# NaN    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
#
# [151 rows x 5 columns]

# %%
print(df.sort_values(by='Petal.Width'))
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 33.0            5.2          4.1           1.5          0.1     setosa
# 14.0            4.3            3           1.1          0.1     setosa
# 13.0            4.8            3           1.4          0.1     setosa
# 38.0            4.9          3.6           1.4          0.1     setosa
# 10.0            4.9          NaN           1.5          0.1     setosa
# ...             ...          ...           ...          ...        ...
# 141.0           6.7          3.1           5.6          2.4  virginica
# 101.0           6.3          3.3             6          2.5  virginica
# 110.0           7.2          3.6           6.1          2.5  virginica
# 145.0           NaN          3.3           5.7          2.5  virginica
# NaN    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
#
# [151 rows x 5 columns]

# %%
print(df.sort_values(by='Sepal.Width'))
# Out:
#       Sepal.Length Sepal.Width Petal.Length Petal.Width     Species
# 61.0             5           2          3.5           1  versicolor
# 63.0             6         2.2            4           1  versicolor
# 120.0            6         2.2            5         1.5   virginica
# 69.0           6.2         2.2          4.5         1.5  versicolor
# 94.0             5         2.3          3.3           1  versicolor
# ...            ...         ...          ...         ...         ...
# 62.0           5.9         NaN          4.2         1.5  versicolor
# 89.0           5.6         NaN          4.1         1.3  versicolor
# 115.0          5.8         NaN          5.1         2.4   virginica
# 134.0          6.3         NaN          5.1         1.5   virginica
# 144.0          6.8         NaN          5.9         2.3   virginica
#
# [151 rows x 5 columns]

# %%
# check for missing values
# the number of missing values in each column
print(df.isnull())
print(df.isnull().sum())
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# NaN           False        False         False        False    False
# 1.0           False        False         False        False    False
# 2.0           False        False         False        False    False
# 3.0           False        False         False        False    False
# 4.0           False        False         False        False    False
# ...             ...          ...           ...          ...      ...
# 146.0         False        False         False        False    False
# 147.0         False        False         False        False    False
# 148.0         False        False         False        False    False
# 149.0         False        False         False        False    False
# 150.0          True        False         False        False    False
#
# [151 rows x 5 columns]
# Sepal.Length     8
# Sepal.Width     11
# Petal.Length     0
# Petal.Width      0
# Species          0
# dtype: int64

# %%
# Total number of missing cells in the entire dataset
total_missing = df.isnull().sum().sum()
print('Total Missing',total_missing)
# Out:
# Total Missing 19

# %%
# df.head()
df.head()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# NaN  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 1.0           5.1          3.5           1.4          0.2   Setosa
# 2.0           4.9            3           1.4          0.2   setosa
# 3.0           4.7          3.2           1.3          0.2   setosa
# 4.0           4.6          3.1           1.5          0.2   setosa

# %%
# try dropping rows from the dataset inplace
df.drop(5,inplace=True)

# %%
# axis=1 to look through column headers and not row index
#Drop ID variable

#inplace
#drop(column_name, axis=1, inplace=True)# Columns gets removed
df.drop('Sepal.Length',axis=1,inplace=True)

# %%
df.head()
# Out:
#      Sepal.Width  Petal.Length  Petal.Width  Species
# NaN  Sepal.Width  Petal.Length  Petal.Width  Species
# 1.0          3.5           1.4          0.2   Setosa
# 2.0            3           1.4          0.2   setosa
# 3.0          3.2           1.3          0.2   setosa
# 4.0          3.1           1.5          0.2   setosa

# %% [markdown]
# Recap - what do each of these things do???
#
#
# - df.shape
# - df.head()
# - df.dtypes
# - df.describe()
#  - Numeric
#  - Non-Numeric
# - df['column'].value_counts()
# - df.isnull().sum()
# - df.isnull().sum().sum()
# - df.drop()

# %% [markdown]
# # [Objective 03](#pandas-visualizations) Describe and discriminate between basic data types

# %% [markdown]
# ## Overview
#
# One of the cornerstones of Exploratory Data Analysis (EDA) is being able to identify variable types.  We will need different statistical methods to display and describe each of these different types of data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('iris_dirty.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           NaN          3.6           1.4          0.2  setosa

# %%
print(df.dtypes)
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  142 non-null    float64
#  1   Sepal.Width   139 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    142.000000   139.000000    150.000000   150.000000
# mean       5.840141     3.043165      3.758000     1.199333
# std        0.831905     0.438550      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Numeric columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Categorical columns
cat_cols = df.select_dtypes(include=['object']).columns

# Boolean columns
bool_cols = df.select_dtypes(include=['bool']).columns

# Date/Time columns (if any)
date_cols = df.select_dtypes(include=['datetime64']).columns

# %%
print("Numeric:", num_cols)
# Out:
# Numeric: Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width'], dtype='object')

# %%
print("Categorical:", cat_cols)
# Out:
# Categorical: Index(['Species'], dtype='object')

# %%
print("Boolean:", bool_cols)
# Out:
# Boolean: Index([], dtype='object')

# %%
print("Date/Time:", date_cols)
# Out:
# Date/Time: Index([], dtype='object')

# %%
for col in cat_cols:
    print(df[col].value_counts())
    print(df[col].value_counts(normalize=True))  # proportions
# Out:
# Species
# virginica     49
# setosa        48
# versicolor    48
# Setosa         1
# SETOSA         1
# Versicolor     1
# VERSICOLOR     1
# VIRGINICA      1
# Name: count, dtype: int64
# Species
# virginica     0.326667
# setosa        0.320000
# versicolor    0.320000
# Setosa        0.006667
# SETOSA        0.006667
# Versicolor    0.006667
# VERSICOLOR    0.006667
# VIRGINICA     0.006667
# Name: proportion, dtype: float64

# %%
# Histograms
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# Box plots
for col in ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
sns.countplot(x='Species', data=df)
plt.title("Count of Species")
plt.show()

# %%
sns.pairplot(df, hue='Species')
plt.show()
